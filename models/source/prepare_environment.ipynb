# %% [markdown]
# ### NOW WE ARE CREATE A NEW PIPELINE DATALAKE HOUSE PIPELINE OPTIMISE TO HANDLE DIFFERENT ISSUE

# %% [markdown]
# #### FIRST TOPIC HERE NEED TO IDENTIFY `UNITE CATALOG` AND THEN DATA SOURCE

# %% [markdown]
# ##### CREATE UNIT CATALOG

# %%
# %sql
CREATE CATALOG IF NOT EXISTS databricks_mdf_catalog;

# %%
# %sql 
SHOW CATALOGS;

# %%
# %sql 
USE CATALOG databricks_mdf_catalog ;

# %%
# %sql 
CREATE SCHEMA IF NOT EXISTS databricks_mdf_catalog.source;
CREATE SCHEMA IF NOT EXISTS databricks_mdf_catalog.bronz;
CREATE SCHEMA IF NOT EXISTS databricks_mdf_catalog.sliver;
CREATE SCHEMA IF NOT EXISTS databricks_mdf_catalog.gold;

# %%
# %sql 
SHOW SCHEMAS ;

# %%
# %sql 
CREATE VOLUME IF NOT EXISTS databricks_mdf_catalog.source.csv_vol;

# %% [markdown]
# ##### HERE REMEMBER 3 LEVEL NAMESPACE( gatalog name | schema name | object name)

# %% [markdown]
# METADATA ACCESS BASE

# %%
# %sql
SELECT *
FROM read_files(
  "/Volumes/databricks_mdf_catalog/source/csv_vol/source_crm/cust_info.csv",
  format => "csv"
)

# %%
# %sql
SELECT *
FROM `csv`.`/Volumes/databricks_mdf_catalog/source/csv_vol/source_crm/cust_info.csv`

# %%
# %sql 
CREATE TABLE IF NOT EXISTS databricks_mdf_catalog.bronz.bronze_cust_info
AS
SELECT *
FROM `csv`.`/Volumes/databricks_mdf_catalog/source/csv_vol/source_crm/cust_info.csv`

# %%
# %sql 
DROP TABLE IF EXISTS databricks_mdf_catalog.bronz.bronze_cust_info;
